# %%
user = ""
password = ""

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd
import time

# %%
class Truth:
    def __init__(self,author,id_,date,text):
        self.author = author
        self.id = id_
        self.text = text
        self.date = date

# %%
def sign_in(driver, username, password):
    driver.get("https://truthsocial.com/login")
    driver.implicitly_wait(2)
    driver.find_element(By.NAME,'username').send_keys(username)
    driver.find_element(By.NAME,'password').send_keys(password)

    for t in driver.find_elements(By.TAG_NAME,'button'):
        if t.text == 'Accept':
            t.click()
      
    for t in driver.find_elements(By.TAG_NAME,'button'):
        if t.text == "Sign in":
            print(t.text)
            t.click()

# %%
def truth_reply_parser(html):
    list_truths = []
    soup = BeautifulSoup(html,'html.parser')
    truths = soup.find_all(attrs={'data-id': True})
    for truth in truths:
        truth_id = truth['data-id']
        truth_author = truth.text.split("@")[1].split("·")[0]
        truth_text = truth.text
        truth_date = truth.text.split("@")[1].split("·")[1].split("Replying")[0]
        list_truths.append(Truth(truth_author, truth_id, truth_date, truth_text))
    
    return list_truths

# %%
driver = webdriver.Chrome()
sign_in(driver,user,password )
# Out:
# Sign in

# %% [markdown]
# # Get trump post ids

# %%
def get_link(author, post_id):
    return f"https://truthsocial.com/@{author}/posts/{post_id}"

# %%
list_truths = []
driver.get("https://truthsocial.com/@realDonaldTrump")
driver.implicitly_wait(5)
counter = 0
last_height = 0

for i in range(10000):
    if i%5 == 4:
        print(i)
        print(len(list_truths))
        print("----------------")
        time.sleep(3)
        break


    try:
        sub_list_truths = truth_reply_parser(driver.page_source)
        for truth in sub_list_truths:
            list_truths.append(truth)

    except:
        print("Error")
        time.sleep(1)


    finally:     
        driver.execute_script(f"window.scrollTo(0, {counter*2160+1080})")
        counter += 1
        time.sleep(2)
        if driver.execute_script("return document.body.scrollHeight") == last_height:
            print("It might be finished")
            time.sleep(3.5)
            driver.execute_script(f"window.scrollTo(0, {counter*2160+1080+540})")
            if driver.execute_script("return document.body.scrollHeight") == last_height:
                print("I have all i needed from this Truth")
                break

        last_height = driver.execute_script("return document.body.scrollHeight")

l = []
for t in list_truths:
    l.append({
        'date':t.date,
        'author':t.author,
        'text':t.text,
        'id':t.id
    })

df_truths = pd.DataFrame(l).drop_duplicates().reset_index(drop=True)
links = []
for i in range(len(df_truths)):
    links.append(get_link(df_truths.author.iloc[i], df_truths.id.iloc[i]))
df_truths['links'] = links
df_truths.to_csv(f"trump.csv")
# Out:
# 4
# 7
# ----------------

# %%
df_truths['links'] = get_link(df_truths.author, df_truths.id)
df_truths
# Out:
#                                                  date           author  \
# 0                                   2h1.54k2.28k9.49k  realDonaldTrump
# 1   2hhttps://dcenquirer.com/watch-in-the-face-of-...  realDonaldTrump
# 2          14hELECTION INTERFERENCE!!!3.16k9.72k38.6k  realDonaldTrump
# 3   14hI will be leaving Mar-a-Lago on Monday at 1...  realDonaldTrump
# %%
df = pd.read_csv('trump.csv',index_col=0)

# %%
list_truths = []

# %% [markdown]
# # Make Sure to Zoom out to 25%

# %%
counter = 0
last_height = 0
for j in range(len(df)):
    driver.get(df.iloc[j].links)
    for i in range(100000):
        if i%25 == 0:
            print(i)
            print(len(list_truths))
            print("----------------")
            time.sleep(3)


        try:
            sub_list_truths = truth_reply_parser(driver.page_source)
            for truth in sub_list_truths:
                list_truths.append(truth)

        except:
            print("Error")
            time.sleep(1)


        finally:     
            driver.execute_script(f"window.scrollTo(0, {counter*2160+1080})")
            counter += 1
            time.sleep(2)
            if driver.execute_script("return document.body.scrollHeight") == last_height:
                print("It might be finished")
                time.sleep(3.5)
                driver.execute_script(f"window.scrollTo(0, {counter*2160+1080+540})")
                if driver.execute_script("return document.body.scrollHeight") == last_height:
                    print("I have all i needed from this Truth")
                    break

            last_height = driver.execute_script("return document.body.scrollHeight")
            
    l = []
    for t in list_truths:
        l.append({
            'date':t.date,
            'author':t.author,
            'text':t.text,
            'id':t.id
        })
        
    df_truths = pd.DataFrame(l).drop_duplicates().reset_index(drop=True)
    df_truths.to_csv(f"{df.iloc[j].Trumps_posts_id}.csv")
# Out:
# 0
# 0
# ----------------
# Error
# Error
# Error
# 25
# 205
# ----------------
# Error
# Error
# 50
# 467
# ----------------
# It might be finished
# I have all i needed from this Truth
# 0
# 481
# ----------------
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# It might be finished
# I have all i needed from this Truth
# 0
# 629
# ----------------
# It might be finished
# I have all i needed from this Truth
# 0
# 629
# ----------------
# Error
# 25
# 819
# ----------------
# 50
# 1029
# ----------------
# It might be finished
# It might be finished
# It might be finished
# Error
# Error
# Error
# Error
# 75
# 1244
# ----------------
# Error
# Error
# Error
# Error
# It might be finished
# 100
# 1444
# ----------------
# It might be finished
# It might be finished
# I have all i needed from this Truth
# 0
# 1511
# ----------------
# 25
# 1763
# ----------------
# Error
# 50
# 1931
# ----------------
# Error
# Error
# Error
# 75
# 2176
# ----------------
# It might be finished
# I have all i needed from this Truth
# 0
# 2190
# ----------------
# Error
# Error
# 25
# 2422
# ----------------
# Error
# Error
# 50
# 2729
# ----------------
# It might be finished
# I have all i needed from this Truth
# 0
# 2898
# ----------------
# Error
# It might be finished
# I have all i needed from this Truth
# 0
# 3072
# ----------------
# Error
# 25
# 3295
# ----------------
# 50
# 3561
# ----------------
# It might be finished
# I have all i needed from this Truth
# 0
# 3595
# ----------------
# Error
# 25
# 3824
# ----------------
# Error
# Error
# Error
# 50
# 4062
# ----------------
# Error
# Error
# Error
# 75
# 4321
# ----------------
# 100
# 4628
# ----------------
# Error
# Error
# 125
# 4865
# ----------------
# Error
# It might be finished
# I have all i needed from this Truth
# 0
# 4905
# ----------------
# It might be finished
# I have all i needed from this Truth
