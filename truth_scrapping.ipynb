# %%
user = "observerAdel"
password = "@Del1654"



from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd
import os
import time



class Truth:
    def __init__(self,author,id_,date,text):
        self.author = author
        self.id = id_
        self.text = text
        self.date = date
        
        

def sign_in(driver, username, password):
    driver.get("https://truthsocial.com/login")
    driver.implicitly_wait(2)
    driver.find_element(By.NAME,'username').send_keys(username)
    driver.find_element(By.NAME,'password').send_keys(password)

    for t in driver.find_elements(By.TAG_NAME,'button'):
        if t.text == 'Accept':
            t.click()
      
    for t in driver.find_elements(By.TAG_NAME,'button'):
        if t.text == "Sign in":
            print(t.text)
            t.click()
            
            
            

def truth_reply_parser(html):
    list_truths = []
    soup = BeautifulSoup(html,'html.parser')
    truths = soup.find_all(attrs={'data-id': True})
    for truth in truths:
        truth_id = truth['data-id']
        truth_author = truth.text.split("@")[1].split("·")[0]
        truth_text = truth.text
        truth_date = truth.text.split("@")[1].split("·")[1].split("Replying")[0]
        list_truths.append(Truth(truth_author, truth_id, truth_date, truth_text))
    
    return list_truths




def get_link(author, post_id):
    return f"https://truthsocial.com/@{author}/posts/{post_id}"


driver = webdriver.Chrome()
sign_in(driver,user,password )


# In[10]:


# df_truths['links'] = get_link(df_truths.author, df_truths.id)
# df_truths


# # Make Sure to Zoom out to 25%

#####################################################
# Out:
# Sign in

# %%
df = pd.read_csv('trump.csv',index_col=0)
counter = 0
last_height = 0
list_truths = []
l = []
print("len df is :")
print(len(df))
for j in range(len(df)):
    if f"{df.iloc[j].id}.csv" in os.listdir():
        print("I have already done this Truth")
        continue


    if j%40==39:
        print("I am going to sleep for 30 minutes")
        time.sleep(15*60)

    driver.get(df.iloc[j].links)
    for i in range(100):
        if i%51 == 50:
            print(i)
            print(len(list_truths))
            print("----------------")
            time.sleep(3)


        try:
            sub_list_truths = truth_reply_parser(driver.page_source)
            for truth in sub_list_truths:
                list_truths.append(truth)

        except:
            # print("Error")
            time.sleep(1)


        finally:     
            driver.execute_script(f"window.scrollTo(0, {counter*2160+1080})")
            counter += 1
            time.sleep(2)
            if driver.execute_script("return document.body.scrollHeight") == last_height:
                time.sleep(3.5)
                driver.execute_script(f"window.scrollTo(0, {counter*2160+1080+540})")
                if driver.execute_script("return document.body.scrollHeight") == last_height:
                    print("I have all i needed from this Truth")
                    break

            last_height = driver.execute_script("return document.body.scrollHeight")
            
            if i%5==4:
                l = []
                for t in list_truths:
                    l.append({
                        'date':t.date,
                        'author':t.author,
                        'text':t.text,
                        'id':t.id
                    })
                df_truths = pd.DataFrame(l).drop_duplicates().reset_index(drop=True)
                # print("------------------------>>>>>  ",len(df_truths))
                if len(df_truths) > 100:
                    print(f"I have more than 100 comments on this {j} Truth")
                    print("*******************************************")
                    break
                        
        
    df_truths = pd.DataFrame(l).drop_duplicates().reset_index(drop=True)
            
    l = []
    for t in list_truths:
        l.append({
            'date':t.date,
            'author':t.author,
            'text':t.text,
            'id':t.id
        })
        
    df_truths = pd.DataFrame(l).drop_duplicates().reset_index(drop=True)
    df_truths.to_csv(f"{df.iloc[j].id}.csv")
    list_truths = []
# Out:
# len df is :
# 6154
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have all i needed from this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have more than 100 comments on this 36 Truth
# *******************************************
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have already done this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have all i needed from this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have already done this Truth
# I have more than 100 comments on this 74 Truth
# *******************************************
# I have more than 100 comments on this 75 Truth
# *******************************************
# I have more than 100 comments on this 76 Truth
# *******************************************
# I have more than 100 comments on this 77 Truth
# *******************************************
# I have more than 100 comments on this 78 Truth
# *******************************************
# I am going to sleep for 30 minutes
# I have more than 100 comments on this 79 Truth
# *******************************************
# I have more than 100 comments on this 80 Truth
# *******************************************
# I have more than 100 comments on this 81 Truth
# *******************************************
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have more than 100 comments on this 84 Truth
# *******************************************
# I have more than 100 comments on this 85 Truth
# *******************************************
# I have more than 100 comments on this 86 Truth
# *******************************************
# I have more than 100 comments on this 87 Truth
# *******************************************
# I have more than 100 comments on this 88 Truth
# *******************************************
# I have more than 100 comments on this 89 Truth
# *******************************************
# I have more than 100 comments on this 90 Truth
# *******************************************
# I have more than 100 comments on this 91 Truth
# *******************************************
# I have more than 100 comments on this 92 Truth
# *******************************************
# I have more than 100 comments on this 93 Truth
# *******************************************
# I have more than 100 comments on this 94 Truth
# *******************************************
# I have more than 100 comments on this 95 Truth
# *******************************************
# 50
# 540
# ----------------
# I have more than 100 comments on this 96 Truth
# *******************************************
# 50
# 301
# ----------------
# I have more than 100 comments on this 97 Truth
# *******************************************
# I have more than 100 comments on this 98 Truth
# *******************************************
# I have more than 100 comments on this 99 Truth
# *******************************************
# I have more than 100 comments on this 100 Truth
# *******************************************
# I have more than 100 comments on this 101 Truth
# *******************************************
# I have more than 100 comments on this 102 Truth
# *******************************************
# I have more than 100 comments on this 103 Truth
# *******************************************
# I have more than 100 comments on this 104 Truth
# *******************************************
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have more than 100 comments on this 107 Truth
# *******************************************
# 50
# 510
# ----------------
# I have more than 100 comments on this 108 Truth
# *******************************************
# I have more than 100 comments on this 109 Truth
# *******************************************
# I have more than 100 comments on this 110 Truth
# *******************************************
# I have more than 100 comments on this 111 Truth
# *******************************************
# I have all i needed from this Truth
# I have more than 100 comments on this 113 Truth
# *******************************************
# I have more than 100 comments on this 114 Truth
# *******************************************
# I have more than 100 comments on this 115 Truth
# *******************************************
# I have more than 100 comments on this 116 Truth
# *******************************************
# I have more than 100 comments on this 117 Truth
# *******************************************
# I have more than 100 comments on this 118 Truth
# *******************************************
# I am going to sleep for 30 minutes
# I have more than 100 comments on this 119 Truth
# *******************************************
# I have more than 100 comments on this 120 Truth
# *******************************************
# I have more than 100 comments on this 121 Truth
# *******************************************
# I have more than 100 comments on this 122 Truth
# *******************************************
# I have more than 100 comments on this 123 Truth
# *******************************************
# I have more than 100 comments on this 124 Truth
# *******************************************
# I have more than 100 comments on this 125 Truth
# *******************************************
# I have all i needed from this Truth
# I have more than 100 comments on this 127 Truth
# *******************************************
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have more than 100 comments on this 130 Truth
# *******************************************
# I have all i needed from this Truth
# I have more than 100 comments on this 132 Truth
# *******************************************
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have more than 100 comments on this 140 Truth
# *******************************************
# I have all i needed from this Truth
# I have more than 100 comments on this 142 Truth
# *******************************************
# I have more than 100 comments on this 143 Truth
# *******************************************
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have more than 100 comments on this 148 Truth
# *******************************************
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have more than 100 comments on this 151 Truth
# *******************************************
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have more than 100 comments on this 157 Truth
# *******************************************
# I have more than 100 comments on this 158 Truth
# *******************************************
# I am going to sleep for 30 minutes
# I have more than 100 comments on this 159 Truth
# *******************************************
# I have more than 100 comments on this 160 Truth
# *******************************************
# I have more than 100 comments on this 161 Truth
# *******************************************
# I have more than 100 comments on this 162 Truth
# *******************************************
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have more than 100 comments on this 166 Truth
# *******************************************
# I have more than 100 comments on this 167 Truth
# *******************************************
# 50
# 614
# ----------------
# I have more than 100 comments on this 168 Truth
# *******************************************
# I have all i needed from this Truth
# I have more than 100 comments on this 170 Truth
# *******************************************
# 50
# 237
# ----------------
# I have more than 100 comments on this 171 Truth
# *******************************************
# 50
# 424
# ----------------
# I have all i needed from this Truth
# 50
# 488
# ----------------
# I have more than 100 comments on this 174 Truth
# *******************************************
# I have more than 100 comments on this 175 Truth
# *******************************************
# I have more than 100 comments on this 176 Truth
# *******************************************
# I have more than 100 comments on this 177 Truth
# *******************************************
# I have more than 100 comments on this 178 Truth
# *******************************************
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have more than 100 comments on this 182 Truth
# *******************************************
# I have more than 100 comments on this 183 Truth
# *******************************************
# I have more than 100 comments on this 184 Truth
# *******************************************
# I have more than 100 comments on this 185 Truth
# *******************************************
# I have more than 100 comments on this 186 Truth
# *******************************************
# I have more than 100 comments on this 187 Truth
# *******************************************
# I have more than 100 comments on this 188 Truth
# *******************************************
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have more than 100 comments on this 192 Truth
# *******************************************
# I have more than 100 comments on this 193 Truth
# *******************************************
# I have more than 100 comments on this 194 Truth
# *******************************************
# I have all i needed from this Truth
# I have more than 100 comments on this 196 Truth
# *******************************************
# 50
# 581
# ----------------
# I have more than 100 comments on this 197 Truth
# *******************************************
# 50
# 594
# ----------------
# I have more than 100 comments on this 198 Truth
# *******************************************
# I am going to sleep for 30 minutes
# I have more than 100 comments on this 199 Truth
# *******************************************
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# 50
# 242
# ----------------
# I have more than 100 comments on this 203 Truth
# *******************************************
# I have more than 100 comments on this 204 Truth
# *******************************************
# 50
# 548
# ----------------
# I have all i needed from this Truth
# I have more than 100 comments on this 207 Truth
# *******************************************
# 50
# 429
# ----------------
# I have more than 100 comments on this 209 Truth
# *******************************************
# I have more than 100 comments on this 210 Truth
# *******************************************
# I have more than 100 comments on this 211 Truth
# *******************************************
# I have more than 100 comments on this 212 Truth
# *******************************************
# I have more than 100 comments on this 213 Truth
# *******************************************
# I have more than 100 comments on this 214 Truth
# *******************************************
# I have more than 100 comments on this 215 Truth
# *******************************************
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have more than 100 comments on this 218 Truth
# *******************************************
# 50
# 367
# ----------------
# I have more than 100 comments on this 219 Truth
# *******************************************
# 50
# 517
# ----------------
# I have more than 100 comments on this 220 Truth
# *******************************************
# I have more than 100 comments on this 221 Truth
# *******************************************
# I have more than 100 comments on this 222 Truth
# *******************************************
# 50
# 489
# ----------------
# I have more than 100 comments on this 223 Truth
# *******************************************
# 50
# 565
# ----------------
# I have more than 100 comments on this 224 Truth
# *******************************************
# I have more than 100 comments on this 225 Truth
# *******************************************
# I have more than 100 comments on this 226 Truth
# *******************************************
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have more than 100 comments on this 229 Truth
# *******************************************
# I have more than 100 comments on this 230 Truth
# *******************************************
# I have more than 100 comments on this 231 Truth
# *******************************************
# I have more than 100 comments on this 232 Truth
# *******************************************
# I have more than 100 comments on this 233 Truth
# *******************************************
# I have more than 100 comments on this 234 Truth
# *******************************************
# 50
# 383
# ----------------
# I have more than 100 comments on this 235 Truth
# *******************************************
# I have all i needed from this Truth
# I have more than 100 comments on this 237 Truth
# *******************************************
# I have more than 100 comments on this 238 Truth
# *******************************************
# I am going to sleep for 30 minutes
# I have more than 100 comments on this 239 Truth
# *******************************************
# I have all i needed from this Truth
# 50
# 555
# ----------------
# I have more than 100 comments on this 241 Truth
# *******************************************
# I have more than 100 comments on this 242 Truth
# *******************************************
# I have more than 100 comments on this 243 Truth
# *******************************************
# I have more than 100 comments on this 244 Truth
# *******************************************
# 50
# 633
# ----------------
# I have more than 100 comments on this 246 Truth
# *******************************************
# 50
# 612
# ----------------
# I have more than 100 comments on this 247 Truth
# *******************************************
# I have more than 100 comments on this 248 Truth
# *******************************************
# I have more than 100 comments on this 249 Truth
# *******************************************
# I have more than 100 comments on this 250 Truth
# *******************************************
# I have more than 100 comments on this 251 Truth
# *******************************************
# I have more than 100 comments on this 252 Truth
# *******************************************
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have more than 100 comments on this 256 Truth
# *******************************************
# I have all i needed from this Truth
# I have more than 100 comments on this 258 Truth
# *******************************************
# 50
# 577
# ----------------
# I have all i needed from this Truth
# I have more than 100 comments on this 260 Truth
# *******************************************
# I have more than 100 comments on this 261 Truth
# *******************************************
# I have more than 100 comments on this 262 Truth
# *******************************************
# I have more than 100 comments on this 263 Truth
# *******************************************
# 50
# 178
# ----------------
# I have more than 100 comments on this 264 Truth
# *******************************************
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have more than 100 comments on this 267 Truth
# *******************************************
# I have more than 100 comments on this 268 Truth
# *******************************************
# I have more than 100 comments on this 269 Truth
# *******************************************
# I have all i needed from this Truth
# I have more than 100 comments on this 271 Truth
# *******************************************
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have more than 100 comments on this 274 Truth
# *******************************************
# I have more than 100 comments on this 275 Truth
# *******************************************
# I have all i needed from this Truth
# 50
# 467
# ----------------
# I have more than 100 comments on this 277 Truth
# *******************************************
# I have more than 100 comments on this 278 Truth
# *******************************************
# I am going to sleep for 30 minutes
# I have more than 100 comments on this 279 Truth
# *******************************************
# 50
# 397
# ----------------
# I have more than 100 comments on this 280 Truth
# *******************************************
# I have more than 100 comments on this 281 Truth
# *******************************************
# I have all i needed from this Truth
# 50
# 411
# ----------------
# I have more than 100 comments on this 283 Truth
# *******************************************
# I have more than 100 comments on this 284 Truth
# *******************************************
# I have more than 100 comments on this 285 Truth
# *******************************************
# I have more than 100 comments on this 286 Truth
# *******************************************
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have more than 100 comments on this 290 Truth
# *******************************************
# I have more than 100 comments on this 291 Truth
# *******************************************
# I have all i needed from this Truth
# I have more than 100 comments on this 293 Truth
# *******************************************
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have more than 100 comments on this 299 Truth
# *******************************************
# I have more than 100 comments on this 300 Truth
# *******************************************
# I have more than 100 comments on this 301 Truth
# *******************************************
# I have more than 100 comments on this 302 Truth
# *******************************************
# I have more than 100 comments on this 303 Truth
# *******************************************
# 50
# 387
# ----------------
# I have more than 100 comments on this 304 Truth
# *******************************************
# I have more than 100 comments on this 305 Truth
# *******************************************
# I have more than 100 comments on this 306 Truth
# *******************************************
# I have more than 100 comments on this 307 Truth
# *******************************************
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have more than 100 comments on this 311 Truth
# *******************************************
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have more than 100 comments on this 315 Truth
# *******************************************
# I have all i needed from this Truth
# I have more than 100 comments on this 317 Truth
# *******************************************
# I have more than 100 comments on this 318 Truth
# *******************************************
# I am going to sleep for 30 minutes
# I have more than 100 comments on this 319 Truth
# *******************************************
# I have more than 100 comments on this 320 Truth
# *******************************************
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have more than 100 comments on this 323 Truth
# *******************************************
# I have more than 100 comments on this 324 Truth
# *******************************************
# I have more than 100 comments on this 325 Truth
# *******************************************
# I have more than 100 comments on this 326 Truth
# *******************************************
# I have more than 100 comments on this 327 Truth
# *******************************************
# I have more than 100 comments on this 328 Truth
# *******************************************
# I have more than 100 comments on this 329 Truth
# *******************************************
# I have more than 100 comments on this 330 Truth
# *******************************************
# I have more than 100 comments on this 331 Truth
# *******************************************
# I have more than 100 comments on this 332 Truth
# *******************************************
# I have more than 100 comments on this 333 Truth
# *******************************************
# I have more than 100 comments on this 334 Truth
# *******************************************
# I have more than 100 comments on this 335 Truth
# *******************************************
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have more than 100 comments on this 340 Truth
# *******************************************
# I have more than 100 comments on this 341 Truth
# *******************************************
# I have all i needed from this Truth
# I have all i needed from this Truth
# I have more than 100 comments on this 344 Truth
# *******************************************
# I have all i needed from this Truth
# I have more than 100 comments on this 346 Truth
# *******************************************
# I have all i needed from this Truth
# I have more than 100 comments on this 348 Truth
# *******************************************
# I have more than 100 comments on this 349 Truth
# *******************************************
# 50
# 584
# ----------------
# 50
# 383
# ----------------
# I have more than 100 comments on this 351 Truth
# *******************************************
# I have more than 100 comments on this 352 Truth
# *******************************************
# I have more than 100 comments on this 353 Truth
# *******************************************
# I have all i needed from this Truth
# I have more than 100 comments on this 355 Truth
# *******************************************
# I have more than 100 comments on this 356 Truth
# *******************************************
# I have more than 100 comments on this 357 Truth
# *******************************************

# %%
import os
import pandas as pd
def delete_empty_files(min_num=30):
    for f_name in os.listdir():
        if f_name.endswith(".csv"):
            df = pd.read_csv(f_name)
            if len(df)<min_num:
                os.remove(f_name)
                print(f_name, " is deleted")

# %%
delete_empty_files()
# Out:
# 110136200056724359.csv  is deleted
